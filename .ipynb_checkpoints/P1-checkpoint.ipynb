# %% [markdown]
# # Project: **Finding Lane Lines on the Road**
# ***

# %% [markdown]
# <div class="alert alert-block alert-warning" style="text-align: justify">Goal is piece together a pipeline to detect the line segments in the image, then average/extrapolate them and draw them onto the image for display (as below).
# After, try it out on the video stream.</br>
# **Tools:** color selection, region of interest selection, grayscaling, Gaussian smoothing, Canny Edge Detection and Hough Tranform line detection.(** Later, explore and try other techniques that were not presented in the lesson**)
# </div>
#
# <figure>
#  <img src="examples/line-segments-example.jpg" width="380" alt="Combined Image" />
#  <figcaption>
#  <p></p>
#  <p style="text-align: center;"> output should look like this (above) after detecting line segments using the helper functions below </p>
#  </figcaption>
# </figure>
#  <p></p>
# <figure>
#  <img src="examples/laneLines_thirdPass.jpg" width="380" alt="Combined Image" />
#  <figcaption>
#  <p></p>
#  <p style="text-align: center;"> Goal is to connect/average/extrapolate line segments to get output like this</p>
#  </figcaption>
# </figure>

# %%
#importing some useful packages
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import cv2
# %matplotlib inline

# %% [markdown]
# ## Reading in Images.

# %%
import os
#reading in images
test_images_input = os.listdir("test_images/")
images=[]
for image in  os.listdir("test_images/"):
    images.append(mpimg.imread(os.path.join("test_images/",image)))
    
for image in images:
    print('This image is:', type(image), 'with dimensions:', image.shape)
# plot with various axes scales
plt.figure(1)
plt.subplot(231)
plt.imshow(images[0],aspect='auto')

plt.subplot(232)
plt.imshow(images[1],aspect='auto')

plt.subplot(233)
plt.imshow(images[2],aspect='auto')

plt.subplot(234)
plt.imshow(images[3],aspect='auto')

plt.subplot(235)
plt.imshow(images[5],aspect='auto')

plt.subplot(236)
plt.imshow(images[5],aspect='auto')
# Out:
# This image is: <class 'numpy.ndarray'> with dimensions: (540, 960, 3)
# This image is: <class 'numpy.ndarray'> with dimensions: (540, 960, 3)
# This image is: <class 'numpy.ndarray'> with dimensions: (540, 960, 3)
# This image is: <class 'numpy.ndarray'> with dimensions: (540, 960, 3)
# This image is: <class 'numpy.ndarray'> with dimensions: (540, 960, 3)
# This image is: <class 'numpy.ndarray'> with dimensions: (540, 960, 3)

# %% [markdown]
# ## Helper Functions

# %%
import math
def grayscale(img):
    """Applies the Grayscale transform
    This will return an image with only one color channel
    but NOTE: to see the returned image as grayscale
    (assuming your grayscaled image is called 'gray')
    you should call plt.imshow(gray, cmap='gray')"""
    return cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    # Or use BGR2GRAY if you read an image with cv2.imread()
    # return cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
def gaussian_blur(img, kernel_size):
    """Applies a Gaussian Noise kernel"""
    return cv2.GaussianBlur(img, (kernel_size, kernel_size), 0)

def canny(img, low_threshold, high_threshold):
    """Applies the Canny transform"""
    return cv2.Canny(img, low_threshold, high_threshold)

def region_of_interest(img, vertices):
    """
    Applies an image mask.
    Only keeps the region of the image defined by the polygon
    formed from `vertices`. The rest of the image is set to black.
    """
    #defining a blank mask to start with
    mask = np.zeros_like(img)                        
    
    #defining a 3 channel or 1 channel color to fill the mask with depending on the input image
    if len(img.shape) > 2: 
        channel_count = img.shape[2]                 
        ignore_mask_color = (255,) * channel_count   # 3 channel color mask
    else:
        ignore_mask_color = 255                      # 1 channel color mask
    # Fill the polygon defined by "vertices".  
    cv2.fillPoly(mask, vertices, ignore_mask_color)  
    masked_image = cv2.bitwise_and(img, mask)        
    return masked_image

    
def draw_lines(img, lines, color=[255, 0, 0], thickness=2):
    for line in lines:
        for x1_avg,y1_avg,x2_avg,y2_avg in line:
            cv2.line(img, (x1_avg, y1_avg), (x2_avg, y2_avg), [0,255,127], thickness)
    """
    Average and/or extrapolate the line segments detected to map out the full extent of the lane lines.
    Details are written in writeup.md
    """
    verticle_lines=[]   #  m=infinity
    horizontal_lines=[] #  m=0
    left_lines=[]   #  m=+ve
    right_lines=[]   #  m=-ve
    postiveSlope=0     #  +veSlopeSUM
    negtiveSlope=0     #  -veSlopeSUM
#     Seperate Left lines & Right Lines
    for line in lines:
        for x1,y1,x2,y2 in line:
# +ve slope --> left lane
            if (y2-y1)/(x2-x1) > 0 and (y2-y1)/(x2-x1)!=float("inf") :
                left_lines.append(line)
                postiveSlope+= ((y2-y1)/(x2-x1))
# -ve slope --> right lane
            elif(y2-y1)/(x2-x1) < 0 and (y2-y1)/(x2-x1)!= float("-inf") :
                right_lines.append(line)
                negtiveSlope+= abs((y2-y1)/(x2-x1))
# INFINITY slope --> i.e only verticle { (x2-x1)== 0 }
            elif (y2-y1)/(x2-x1)== float("inf") or (y2-y1)/(x2-x1)== float("-inf")   :
                verticle_lines.append(line)
# 0 slope --> only horizontal
            elif (y2-y1)/(x2-x1) ==0 :
    # x-axis <500 --> left lane.
                if x2<500 or x1<500:
                    left_lines.append(line)
    # x-axis >500 --> right lane
                else:
                    right_lines.append(line)
                
#    coordinates average left_lanes , right_lanes
    LL_avg= np.average(left_lines, axis=0)
#     print('LL_avg',LL_avg)
    RL_avg= np.average(right_lines, axis=0)
#     print('RL_avg',RL_avg)
#    calculate the slope_avg & Intercept_avg for left_lanes , right_lanes
    for x1_avg,y1_avg,x2_avg,y2_avg in LL_avg:
#         print(x1_avg,y1_avg,x2_avg,y2_avg)
        LL_slope_avg     = (y2_avg - y1_avg)/(x2_avg - x1_avg)+1
        LL_Intercept_avg = y1_avg - (LL_slope_avg * x1_avg)
        
    for x1_avg,y1_avg,x2_avg,y2_avg in RL_avg:
#         print(x1_avg,y1_avg,x2_avg,y2_avg)
        RL_slope_avg     = (y2_avg - y1_avg)/(x2_avg - x1_avg)-1
        RL_Intercept_avg = y1_avg - (RL_slope_avg * x1_avg)
        
#    Calc the Lowest coordinate for left_lanes & right_lanes using x = (y - b)/m
    min_left_y  =  539#find_minimum_y(left_lines)
    min_left_x  =  calculate_x(min_left_y, LL_Intercept_avg, LL_slope_avg)
    
    min_right_y =  539#find_minimum_y(right_lines)
    min_right_x =  calculate_x(min_right_y, RL_Intercept_avg, RL_slope_avg)

#    Calc the highest coordinate for left_lanes & right_lanes using x = (y - b)/m
    max_left_y  =  280#find_maximum_y(left_lines)
    max_left_x  =  calculate_x(max_left_y,LL_Intercept_avg, LL_slope_avg)
    
    max_right_y =  260#find_maximum_y(right_lines)    
    max_right_x =  calculate_x(max_right_y,RL_Intercept_avg, RL_slope_avg)
    print('Final LEFT coordinates  :','Min x:',min_left_x,'Min y:', min_left_y,'Max x :',max_left_x,'Max y',max_left_y)
    print('Final RIGHT coordinates :','Min x:',min_right_x,'Min y', min_right_y,'Max x:',max_right_x,'Max y',max_right_y)
    """
    This function draws `lines` with `color` and `thickness`. 
    If you want to make the lines semi-transparent, 
    think about combining this function with the weighted_img() function below
    """
    print('Image over')
#   left_lane_lines drawn:  ==================                                         
    cv2.line(img, (min_left_x, min_left_y), (max_left_x, max_left_y), [255,255,0], thickness)
#   right_lane_lines drawn  ==================  
    cv2.line(img, (min_right_x, min_right_y), (max_right_x, max_right_y), color, thickness)
    
def hough_lines(img, rho, theta, threshold, min_line_len, max_line_gap):
    """
    `img` should be the output of a Canny transform.
        
    Returns an image with hough lines drawn.
    """
    lines = cv2.HoughLinesP(img, rho, theta, threshold, np.array([]), minLineLength=min_line_len, maxLineGap=max_line_gap)
    # by using the dimensions of original image, creating a complete Blacked out copy of it.
    line_img = np.zeros((img.shape[0], img.shape[1], 3), dtype=np.uint8) 
    # calling the draw_lines function, which will draws lines on
    # the hough returned coordinates in fully Blacked-out Image.
    draw_lines(line_img, lines)                                             
    # this image has connected(line drawn) coordinates in complete Black-out image. 
    return line_img

# Python 3 has support for cool math symbols.
def weighted_img(img, initial_img, α=0.8, β=1., λ=0.):
    """
    `img` is the output of the hough_lines(), An image with lines drawn on it.
    Should be a blank image (all black) with lines drawn on it.
    
    `initial_img` should be the image before any processing.
    
    The result image is computed as follows:
    
    initial_img * α + img * β + λ
    NOTE: initial_img and img must be the same shape!
    """
    return cv2.addWeighted(initial_img, α, img, β, λ)

# %% [markdown]
# ## Added Helper functions to support draw_lines() .

# %%
'''
Question: I still did not get clarity on Why I have to calculate x when I can retrive exact x_min for y_min as well as maxs.?????????
slope intercept form(x = (y - b)/m)
'''    
def calculate_x(y,intercept, slope):
    x= ((y-intercept)//slope)
    return int(x)
'''
This function simply calculates the min of all y's (y1 & y2) and catches their corresponding x's., But due to the issue mentioned above
I calculted x's for y's with the help of calc_x() function.
'''
def find_minimum_y(lane_lines):
    for line in lane_lines:
        temp=960
        temp1=960
        for x1,y1,x2,y2 in line:
            if temp>=y1:
                temp=y1
                if temp==y1:
                    temp_x1=x1
            if temp1>=y2:
                temp1=y2
                if temp1==y2:
                    temp1_x2=x2
    if temp<temp1:
        min_y=temp
        min_x=temp_x1
    else:
        min_y=temp1
        min_x=temp1_x2
    return int(min_y)
'''
function calculate maximum y
'''
def find_maximum_y(lane_lines):
    for line in lane_lines:
        temp=0
        temp1=0
        for x1,y1,x2,y2 in line:
            if temp<=y1:
                temp=y1
                if temp==y1:
                    temp_x1=x1
            if temp1<=y2:
                temp1=y2
                if temp1==y2:
                    temp1_x2=x2
    if temp>temp1:
        max_y=temp
        max_x=temp_x1
    else:
        max_y=temp1
        max_x=temp1_x2    
    return int(max_y)

# %% [markdown]
# ## Reading Test Images

# %%
import os,re
INPUT_PATH  = 'test_images/'
OUTPUT_PATH = 'test_images_output/'
# Automate the data fetching process.
def read_save_images(input_dir=INPUT_PATH, output_dir=OUTPUT_PATH):           
    #     read input images into a list
    test_images_input = os.listdir(input_dir)                                 
    #     output directory doesn't exist then create one
    if not os.path.isdir(output_dir):                                         
        os.makedirs(output_dir)
    
    for text_images in test_images_input:
        # read each image into program
        image = mpimg.imread( os.path.join(input_dir,text_images))   
        # send this image to your pipeline to process it
        pipeLine_output_image = laneFindingPipeLine(image)                    
        modify_name = re.sub(r'\.jpg$', '', text_images)
        # put the final image into the directory
        mpimg.imsave( os.path.join(output_dir,modify_name+'_output.jpg'),pipeLine_output_image) 
    return

# %% [markdown]
# ### Calling the pipeline

# %%
# simply calling the pipeline here
read_save_images()
# Out:
# Final LEFT coordinates  : Min x: 662 Min y: 539 Max x : 370 Max y 280
# Final RIGHT coordinates : Min x: 342 Min y 539 Max x: 954 Max y 260
# Image over
# Final LEFT coordinates  : Min x: 656 Min y: 539 Max x : 344 Max y 280
# Final RIGHT coordinates : Min x: 148 Min y 539 Max x: 814 Max y 260
# Image over
# Final LEFT coordinates  : Min x: 829 Min y: 539 Max x : 434 Max y 280
# Final RIGHT coordinates : Min x: 283 Min y 539 Max x: 737 Max y 260
# Image over
# Final LEFT coordinates  : Min x: 830 Min y: 539 Max x : 444 Max y 280
# Final RIGHT coordinates : Min x: 389 Min y 539 Max x: 1041 Max y 260
# Image over
# Final LEFT coordinates  : Min x: 753 Min y: 539 Max x : 416 Max y 280
# Final RIGHT coordinates : Min x: 362 Min y 539 Max x: 1012 Max y 260
# Image over
# Final LEFT coordinates  : Min x: 775 Min y: 539 Max x : 388 Max y 280
# Final RIGHT coordinates : Min x: 240 Min y 539 Max x: 780 Max y 260
# Image over

# %% [markdown]
# ## Building a Lane Finding Pipeline

# %%
def laneFindingPipeLine(img):
#     plt.figure(2)
#     print('Original_image shape',img.shape )
#     plt.subplot(331)
#     plt.imshow(img,aspect='auto')
    '''
     to apply canny algorithm, convert color image to gray i,e a single channel image
     gray image helps us to clearly identify, DARK/ BRIGHT/ GRAY(in between) pixels in the image. 
     Also, rapid changing in the brightess, we will be able to find edges/dots
    '''
    gray_image = grayscale(img)
#     print('gray_image shape',gray_image.shape )
#     plt.subplot(332)
#     plt.imshow(gray_image,aspect='auto')
    
    '''
    filter-out noise and spurious gradients by averaging  with gaussian filter, keeping Kernel_size = 5, **always select a odd size number.
    '''
    kernel_size=5
    blur_gray = gaussian_blur(gray_image, kernel_size)
#     print('blur_gray shape',blur_gray.shape )
#     plt.subplot(333)
#     plt.imshow(blur_gray,aspect='auto')
    '''
    now, we can apply canny algorithm, that
    apply its gaussian filter--> finds the gradient strength & direction(you get thick edges)-->apply non-max. suppression(get thin/candidate edges)-->Hysteresis with the help of thresholds specifies in the arguments
    '''
    low_threshold  = 70
    high_threshold = 140
    canny_edges = canny(blur_gray, low_threshold, high_threshold)
#     print('canny_edges shape',canny_edges.shape )
#     plt.subplot(334)
#     plt.imshow(canny_edges,aspect='auto')
    '''
    Work is not done YET..!!
    We just have dotted-lane-lines detected.
    So, we connect them..? How we know which dot to connect with which other dot, & how many dots to connect? ...TRICKY SITUATION...!!!
    Awesome Manipulation by hough, We have dots in our image space, which equivalent to a line for each dot in Hough space. And, collinear points in image space
    is equivalent to respective lines passing through common intersection point/pixel in Hough space. Also, in Hough space we have grids cells, which helps to 
    catch all the edges/dots in images space which are not collinear but very much near to collinear points by adjusting THRESHOLD parameter in below function.
    The more count we get of lines passing through a grid pixel in hough space, the more we get collinear/near-collinear edges/dots in out image space.
    This way we will be able to clear identify the sequence of coordinates of all near-collinear points in the canny_edge_detected_masked_image ....AMAZING..!!
    
    Now, you have the coordinates, Connect them with a line, by calling custom draw_lines()
    '''
    rho = 1
    theta = np.pi/180
    threshold = 12
    min_line_len = 10
    max_line_gap = 2
    line_img = hough_lines(canny_edges, rho, theta, threshold, min_line_len, max_line_gap) # --> will call draw lines & you get a Blacked-out image with connected Hough returned coordinates.
#     print('line_img shape',line_img.shape )
#     plt.subplot(335)
#     plt.imshow(line_img,aspect='auto')
    '''
    Now, you have a edge-detected image : which has edges all over the image based on you detection criterion. This doesn't solve our purpose. 
    We need to narrow-down our area of visibility to not to let our algorithm confuse.
    Create a region of interest, a polygon around the specific lane line.
    This function takes the coordinates of the polygon and draws a polygon in the image,
    then fill with a RED color <-- this becomes your mask.(a specific area to look on.)
    then it performs bitwise AND with canny_edge_detected_image(which is full of edges everywhere) & mask_image(just a plane RED POLYGON SHAPE in the image)--> gives a canny_edge_detected_masked_image
    So, now you have clear RED-HIGHLIGHTNED canny- edges....BEAUTIFULL..!!! :)
    
    Note: Create a mask is independent of any operatio, Moreover, you want to create Mask on the line_image that's why you have to 
          do a bit-wise AND to get only the masked-line Image. Do not repeat it again...!!!!
    '''
    vertices = np.array([[(0,539),(425, 340), (510, 320), (959,539)]], dtype=np.int32)
    masked_image = region_of_interest(img, vertices)
#     print('masked_image shape',masked_image.shape )
#     plt.subplot(336)
#     plt.imshow(masked_image,aspect='auto')
    '''
    have to mask the line_image so that we can get the specific area in the image to look on
    '''
    masked_line_img = cv2.bitwise_and(masked_image, line_img)
#     print('masked_line_img shape',masked_line_img.shape )
#     plt.subplot(337)
#     plt.imshow(masked_line_img,aspect='auto')
    '''
    now we have 1. a image with hough generated connected coordinates
                2. a image with masked-region(polygon) with canny detected edges. 
    this function will give weights to each pixel & glue them together. 
    Remember, before gluing, the dimension shoudld be same, else it pops out errors.
    img==1 & initial_img==2(original image)
    '''
    output = weighted_img(masked_line_img, img, α=0.8, β=1., λ=0.)
#     print('output shape',output.shape )
#     plt.subplot(338)
#     plt.imshow(output,aspect='auto')
    return output

# %% [markdown]
# ## Test on Videos
#
# You know what's cooler than drawing lanes over images? Drawing lanes over video!
#
# We can test our solution on two provided videos:
#
# `solidWhiteRight.mp4`
#
# `solidYellowLeft.mp4`
#
# **Note: if you get an import error when you run the next cell, try changing your kernel (select the Kernel menu above --> Change Kernel). Still have problems? Try relaunching Jupyter Notebook from the terminal prompt. Also, consult the forums for more troubleshooting tips.**
#
# **If you get an error that looks like this:**
# ```
# NeedDownloadError: Need ffmpeg exe.
# You can download it by calling:
# imageio.plugins.ffmpeg.download()
# ```
# **Follow the instructions in the error message and check out [this forum post](https://discussions.udacity.com/t/project-error-of-test-on-videos/274082) for more troubleshooting tips across operating systems.**

# %%
# Import everything needed to edit/save/watch video clips
from moviepy.editor import VideoFileClip
from IPython.display import HTML

# %%
if not os.path.isdir('test_videos_output/'):         #     output directory doesn't exist then create one
        os.makedirs('test_videos_output/')
    
image = mpimg.imread(os.path.join('test_images_output/solidWhiteRight_output.jpg'))
print('output shape',image.shape )
plt.imshow(image,aspect='auto') 
plt.show()
def process_image(image):
    # NOTE: The output you return should be a color image (3 channel) for processing video below
    # TODO: put your pipeline here,
    # you should return the final output (image where lines are drawn on lanes)  
    result = laneFindingPipeLine(image)   
    return result
# Out:
# output shape (540, 960, 4)

# %% [markdown]
# Let's try the one with the solid white lane on the right first ...

# %%
white_output = 'test_videos_output/solidWhiteRight.mp4'
## To speed up the testing process you may want to try your pipeline on a shorter subclip of the video
## To do so add .subclip(start_second,end_second) to the end of the line below
## Where start_second and end_second are integer values representing the start and end of the subclip
## You may also uncomment the following line for a subclip of the first 5 seconds
##clip1 = VideoFileClip("test_videos/solidWhiteRight.mp4").subclip(0,5)
clip1 = VideoFileClip("test_videos/solidWhiteRight.mp4")
white_clip = clip1.fl_image(process_image) #NOTE: this function expects color images!!
# %time white_clip.write_videofile(white_output, audio=False)
# Out:
# Final left coordinates 601 445 889 454
# Final right coordinates 893 320 294 327
# Image over
# [MoviePy] >>>> Building video test_videos_output/solidWhiteRight.mp4
# [MoviePy] Writing video test_videos_output/solidWhiteRight.mp4
#   3%|▎         | 7/222 [00:00<00:03, 60.54it/s]
# Final left coordinates 601 445 889 454
# Final right coordinates 893 320 294 327
# Image over
# Final left coordinates 559 482 856 491
# Final right coordinates 936 437 306 450
# Image over
# Final left coordinates 506 412 794 415
# Final right coordinates 1074 445 466 453
# Image over
# Final left coordinates 468 369 759 380
# Final right coordinates 845 404 239 419
# Image over
# Final left coordinates 471 27 741 29
# Final right coordinates 985 376 358 389
# Image over
# Final left coordinates 446 331 718 334
# Final right coordinates 1032 389 345 395
# Image over
# Final left coordinates 431 237 706 237
# Final right coordinates 1043 344 366 352
# Image over
# Final left coordinates 432 392 726 405
# Final right coordinates 898 467 280 473
# Image over
# Final left coordinates 390 328 684 337
# Final right coordinates 945 492 281 500
# Image over
# Final left coordinates 407 413 706 422
# Final right coordinates 891 369 212 377
# Image over
# Final left coordinates 378 448 687 455
# Final right coordinates 1053 492 360 505
# Image over
# Final left coordinates 323 457 633 463
# Final right coordinates 929 468 241 479
# Image over
# Final left coordinates 365 434 702 441
# Final right coordinates 927 439 241 451
# Image over
# Final left coordinates 336 512 665 519
# Final right coordinates 924 429 222 524
# Image over
#  11%|█         | 24/222 [00:00<00:02, 68.03it/s]
# Final left coordinates 358 508 670 516
# Final right coordinates 786 401 62 428
# Image over
# Final left coordinates 307 509 610 517
# Final right coordinates 1079 529 371 539
# Image over
# Final left coordinates 357 234 658 241
# Final right coordinates 864 379 213 452
# Image over
# Final left coordinates 365 380 642 388
# Final right coordinates 1021 530 271 539
# Image over
# Final left coordinates 410 259 694 260
# Final right coordinates 920 395 266 400
# Image over
# Final left coordinates 376 395 663 408
# Final right coordinates 1010 525 314 535
# Image over
# Final left coordinates 328 407 622 414
# Final right coordinates 694 227 41 230
# Image over
# Final left coordinates 331 232 634 233
# Final right coordinates 878 478 223 489
# Image over
# Final left coordinates 326 413 639 421
# Final right coordinates 877 512 254 537
# Image over
# Final left coordinates 365 417 685 429
# Final right coordinates 994 461 338 474
# Image over
# Final left coordinates 332 440 653 449
# Final right coordinates 837 523 140 538
# Image over
# Final left coordinates 264 528 608 538
# Final right coordinates 922 478 321 486
# Image over
# Final left coordinates 254 496 580 504
# Final right coordinates 992 361 335 381
# Image over
# Final left coordinates 369 248 682 249
# Final right coordinates 796 380 149 399
# Image over
# Final left coordinates 338 353 609 355
# Final right coordinates 862 366 141 378
# Image over
# Final left coordinates 339 240 613 242
# Final right coordinates 1025 498 291 508
# Image over
#  18%|█▊        | 41/222 [00:00<00:02, 74.06it/s]
# Final left coordinates 351 237 631 240
# Final right coordinates 942 327 200 341
# Image over
# Final left coordinates 375 341 658 344
# Final right coordinates 661 329 -76 340
# Image over
# Final left coordinates 342 345 633 347
# Final right coordinates 852 431 136 470
# Image over
# Final left coordinates 349 406 632 420
# Final right coordinates 948 523 199 538
# Image over
# Final left coordinates 322 400 615 403
# Final right coordinates 837 336 103 346
# Image over
# Final left coordinates 329 419 642 427
# Final right coordinates 843 513 179 520
# Image over
# Final left coordinates 238 407 571 410
# Final right coordinates 766 519 106 538
# Image over
# Final left coordinates 289 519 605 532
# Final right coordinates 821 496 86 538
# Image over
# Final left coordinates 305 406 633 410
# Final right coordinates 984 356 266 363
# Image over
# Final left coordinates 321 518 629 526
# Final right coordinates 948 515 218 529
# Image over
# Final left coordinates 330 529 611 539
# Final right coordinates 1106 324 366 337
# Image over
# Final left coordinates 333 364 627 368
# Final right coordinates 994 529 229 538
# Image over
# Final left coordinates 335 286 624 286
# Final right coordinates 904 331 288 347
# Image over
# Final left coordinates 332 481 614 481
# Final right coordinates 1035 528 335 538
# Image over
# Final left coordinates 357 514 647 515
# Final right coordinates 985 467 221 486
# Image over
# Final left coordinates 337 411 623 419
# Final right coordinates 1033 446 272 473
# Image over
#  25%|██▍       | 55/222 [00:00<00:02, 70.55it/s]
# Final left coordinates 324 410 638 423
# Final right coordinates 1044 503 363 515
# Image over
# Final left coordinates 285 388 599 391
# Final right coordinates 827 414 177 426
# Image over
# Final left coordinates 311 452 625 466
# Final right coordinates 902 335 228 346
# Image over
# Final left coordinates 283 482 607 497
# Final right coordinates 705 500 7 517
# Image over
# Final left coordinates 307 474 629 496
# Final right coordinates 806 517 164 538
# Image over
# Final left coordinates 375 523 687 524
# Final right coordinates 842 485 102 506
# Image over
# Final left coordinates 324 115 619 122
# Final right coordinates 790 469 114 538
# Image over
# Final left coordinates 372 282 651 282
# Final right coordinates 863 368 168 372
# Image over
# Final left coordinates 396 391 680 399
# Final right coordinates 776 322 92 328
# Image over
# Final left coordinates 384 254 678 257
# Final right coordinates 768 201 109 204
# Image over
# Final left coordinates 282 409 572 421
# Final right coordinates 890 521 157 537
# Image over
# Final left coordinates 372 374 664 378
# Final right coordinates 872 363 177 376
# Image over
# Final left coordinates 312 361 616 363
# Final right coordinates 911 454 193 468
# Image over
# Final left coordinates 293 386 598 389
# Final right coordinates 932 484 204 491
# Image over
#  31%|███       | 69/222 [00:00<00:02, 64.51it/s]
# Final left coordinates 315 399 624 402
# Final right coordinates 1002 516 295 524
# Image over
# Final left coordinates 315 496 643 503
# Final right coordinates 966 437 268 444
# Image over
# Final left coordinates 357 487 662 496
# Final right coordinates 833 475 107 493
# Image over
# Final left coordinates 324 528 631 535
# Final right coordinates 613 459 -90 467
# Image over
# Final left coordinates 356 530 632 538
# Final right coordinates 883 517 188 523
# Image over
# Final left coordinates 358 376 637 390
# Final right coordinates 871 378 134 393
# Image over
# Final left coordinates 372 342 659 344
# Final right coordinates 963 518 227 530
# Image over
# Final left coordinates 361 397 648 405
# Final right coordinates 1009 433 275 441
# Image over
# Final left coordinates 356 234 646 235
# Final right coordinates 897 511 235 518
# Image over
# Final left coordinates 324 423 623 432
# Final right coordinates 961 440 212 456
# Image over
# Final left coordinates 330 409 633 419
# Final right coordinates 909 528 194 538
# Image over
# Final left coordinates 346 432 657 443
# Final right coordinates 1070 361 307 381
# Image over
# Final left coordinates 308 398 618 401
# Final right coordinates 900 447 159 463
# Image over
#  38%|███▊      | 84/222 [00:01<00:02, 66.18it/s]
# Final left coordinates 321 527 637 538
# Final right coordinates 983 445 248 463
# Image over
# Final left coordinates 327 470 645 486
# Final right coordinates 897 511 176 535
# Image over
# Final left coordinates 339 482 650 526
# Final right coordinates 798 218 45 221
# Image over
# Final left coordinates 375 253 671 255
# Final right coordinates 937 421 271 466
# Image over
# Final left coordinates 393 382 674 390
# Final right coordinates 982 364 329 376
# Image over
# Final left coordinates 387 340 686 343
# Final right coordinates 788 449 155 490
# Image over
# Final left coordinates 355 211 643 215
# Final right coordinates 848 373 117 376
# Image over
# Final left coordinates 360 390 658 400
# Final right coordinates 887 371 153 374
# Image over
# Final left coordinates 321 381 613 384
# Final right coordinates 911 512 151 538
# Image over
# Final left coordinates 409 405 702 423
# Final right coordinates 823 356 119 363
# Image over
# Final left coordinates 361 446 671 466
# Final right coordinates 786 337 93 348
# Image over
# Final left coordinates 345 478 652 489
# Final right coordinates 894 426 223 447
# Image over
# Final left coordinates 340 525 675 532
# Final right coordinates 963 374 219 403
# Image over
# Final left coordinates 314 487 636 500
# Final right coordinates 1038 427 298 444
# Image over
#  44%|████▍     | 98/222 [00:01<00:01, 65.46it/s]
# Final left coordinates 338 501 646 530
# Final right coordinates 833 403 167 473
# Image over
# Final left coordinates 343 364 635 367
# Final right coordinates 945 427 267 437
# Image over
# Final left coordinates 340 318 623 319
# Final right coordinates 952 433 333 443
# Image over
# Final left coordinates 349 387 639 389
# Final right coordinates 1009 460 369 511
# Image over
# Final left coordinates 382 392 680 410
# Final right coordinates 1027 430 425 434
# Image over
# Final left coordinates 364 385 661 388
# Final right coordinates 1013 478 375 497
# Image over
# Final left coordinates 361 381 672 384
# Final right coordinates 1021 454 348 474
# Image over
# Final left coordinates 329 347 639 352
# Final right coordinates 1032 447 376 455
# Image over
# Final left coordinates 337 427 658 434
# Final right coordinates 1021 468 348 476
# Image over
# Final left coordinates 304 425 644 482
# Final right coordinates 969 343 356 354
# Image over
# Final left coordinates 310 446 645 461
# Final right coordinates 923 437 278 447
# Image over
# Final left coordinates 296 511 627 520
# Final right coordinates 851 523 230 538
# Image over
# Final left coordinates 313 527 629 538
# Final right coordinates 900 512 139 521
# Image over
# Final left coordinates 336 527 630 538
# Final right coordinates 868 527 243 536
# Image over
#  50%|█████     | 112/222 [00:01<00:01, 65.89it/s]
# Final left coordinates 405 384 682 391
# Final right coordinates 922 392 161 406
# Image over
# Final left coordinates 367 256 653 257
# Final right coordinates 953 516 289 537
# Image over
# Final left coordinates 406 394 708 408
# Final right coordinates 1052 514 405 525
# Image over
# Final left coordinates 321 400 619 408
# Final right coordinates 774 412 93 451
# Image over
# Final left coordinates 360 390 666 393
# Final right coordinates 781 335 81 345
# Image over
# Final left coordinates 335 437 650 445
# Final right coordinates 894 459 286 533
# Image over
# Final left coordinates 318 445 634 465
# Final right coordinates 919 355 261 365
# Image over
# Final left coordinates 296 437 605 447
# Final right coordinates 822 225 73 228
# Image over
# Final left coordinates 243 493 575 500
# Final right coordinates 875 517 163 538
# Image over
# Final left coordinates 283 480 592 489
# Final right coordinates 898 412 90 441
# Image over
# Final left coordinates 319 479 619 487
# Final right coordinates 842 353 -4 392
# Image over
# Final left coordinates 303 296 589 296
# Final right coordinates 873 459 45 474
# Image over
# Final left coordinates 330 298 604 299
# Final right coordinates 1006 530 182 538
# Image over
# Final left coordinates 374 394 667 396
# Final right coordinates 840 349 153 357
# Image over
#  57%|█████▋    | 126/222 [00:01<00:01, 67.26it/s]
# Final left coordinates 350 395 631 396
# Final right coordinates 887 415 146 439
# Image over
# Final left coordinates 292 253 565 253
# Final right coordinates 1157 478 362 486
# Image over
# Final left coordinates 343 418 630 427
# Final right coordinates 1059 440 295 464
# Image over
# Final left coordinates 318 427 618 444
# Final right coordinates 977 450 268 484
# Image over
# Final left coordinates 323 431 614 437
# Final right coordinates 1037 517 244 536
# Image over
# Final left coordinates 292 394 605 396
# Final right coordinates 905 424 230 463
# Image over
# Final left coordinates 313 457 616 467
# Final right coordinates 825 447 68 472
# Image over
# Final left coordinates 292 529 605 538
# Final right coordinates 963 345 228 353
# Image over
# Final left coordinates 308 496 609 502
# Final right coordinates 713 351 26 379
# Image over
# Final left coordinates 323 513 605 527
# Final right coordinates 969 514 211 539
# Image over
# Final left coordinates 367 217 648 220
# Final right coordinates 772 504 62 539
# Image over
# Final left coordinates 338 371 616 372
# Final right coordinates 989 486 327 493
# Image over
# Final left coordinates 331 390 609 400
# Final right coordinates 608 273 -115 277
# Image over
# Final left coordinates 333 318 613 326
# Final right coordinates 888 348 143 420
# Image over
#  63%|██████▎   | 140/222 [00:02<00:01, 65.88it/s]
# Final left coordinates 284 420 571 428
# Final right coordinates 996 450 328 457
# Image over
# Final left coordinates 310 418 599 429
# Final right coordinates 1047 428 368 438
# Image over
# Final left coordinates 287 425 586 442
# Final right coordinates 1013 409 295 434
# Image over
# Final left coordinates 288 468 594 491
# Final right coordinates 958 519 214 538
# Image over
# Final left coordinates 307 443 625 457
# Final right coordinates 896 341 238 348
# Image over
# Final left coordinates 290 528 607 539
# Final right coordinates 959 334 211 343
# Image over
# Final left coordinates 330 519 636 530
# Final right coordinates 812 365 73 491
# Image over
# Final left coordinates 336 518 619 529
# Final right coordinates 1032 528 296 538
# Image over
# Final left coordinates 344 372 614 380
# Final right coordinates 987 457 269 464
# Image over
# Final left coordinates 318 347 595 352
# Final right coordinates 957 383 323 392
# Image over
# Final left coordinates 338 299 610 306
# Final right coordinates 1083 531 352 538
# Image over
# Final left coordinates 312 388 595 398
# Final right coordinates 808 530 132 537
# Image over
# Final left coordinates 289 408 587 416
# Final right coordinates 1053 369 455 376
# Image over
# Final left coordinates
#  66%|██████▌   | 147/222 [00:02<00:01, 64.87it/s]
#  289 411 582 427
# Final right coordinates 1030 525 322 538
# Image over
# Final left coordinates 300 320 616 327
# Final right coordinates 850 331 195 339
# Image over
# Final left coordinates 294 404 596 407
# Final right coordinates 961 506 277 538
# Image over
# Final left coordinates 265 407 595 410
# Final right coordinates 883 507 218 519
# Image over
# Final left coordinates 285 507 603 524
# Final right coordinates 900 361 238 391
# Image over
# Final left coordinates 312 505 609 512
# Final right coordinates 1078 490 341 505
# Image over
# Final left coordinates 300 310 589 310
# Final right coordinates 1107 457 432 464
# Image over
# Final left coordinates 335 375 611 389
# Final right coordinates 844 358 204 375
# Image over
# Final left coordinates 339 249 609 251
# Final right coordinates 844 363 158 376
# Image over
# Final left coordinates 375 331 648 333
# Final right coordinates 904 420 188 433
# Image over
# Final left coordinates 314 408 591 415
# Final right coordinates 882 394 162 401
# Image over
#  69%|██████▉   | 154/222 [00:02<00:01, 63.42it/s]
# Final left coordinates 325 411 608 427
# Final right coordinates 967 342 229 355
# Image over
# Final left coordinates 361 355 649 360
# Final right coordinates 932 446 218 462
# Image over
# Final left coordinates 318 452 601 460
# Final right coordinates 997 472 283 480
# Image over
#  73%|███████▎  | 161/222 [00:02<00:00, 64.61it/s]
# Final left coordinates 306 357 615 363
# Final right coordinates 1059 455 390 465
# Image over
# Final left coordinates 340 244 649 244
# Final right coordinates 848 486 161 524
# Image over
# Final left coordinates 299 488 608 505
# Final right coordinates 888 373 171 384
# Image over
# Final left coordinates 323 473 613 508
# Final right coordinates 817 407 148 414
# Image over
# Final left coordinates 358 511 641 518
# Final right coordinates 923 524 258 532
# Image over
# Final left coordinates 357 282 626 282
# Final right coordinates 1133 454 501 459
# Image over
# Final left coordinates 316 131 583 135
# Final right coordinates 929 461 282 469
# Image over
# Final left coordinates 341 230 608 232
# Final right coordinates 1012 521 337 529
# Image over
# Final left coordinates 314 165 588 169
# Final right coordinates 996 469 366 475
# Image over
# Final left coordinates 359 408 634 421
# Final right coordinates 865 530 216 539
# Image over
# Final left coordinates 374 387 649 390
# Final right coordinates 714 523 68 537
# Image over
#  76%|███████▌  | 168/222 [00:02<00:00, 64.00it/s]
# Final left coordinates 305 221 579 223
# Final right coordinates 837 318 182 324
# Image over
# Final left coordinates 282 464 565 471
# Final right coordinates 870 446 273 457
# Image over
#  79%|███████▉  | 175/222 [00:02<00:00, 64.14it/s]
# Final left coordinates 299 415 601 418
# Final right coordinates 840 442 185 490
# Image over
# Final left coordinates 309 529 607 537
# Final right coordinates 726 363 91 369
# Image over
# Final left coordinates 344 499 638 511
# Final right coordinates 922 415 286 529
# Image over
# Final left coordinates 380 525 660 534
# Final right coordinates 885 356 256 374
# Image over
# Final left coordinates 356 249 617 250
# Final right coordinates 672 498 23 506
# Image over
# Final left coordinates 375 314 645 314
# Final right coordinates 840 348 185 367
# Image over
# Final left coordinates 382 128 651 132
# Final right coordinates 682 351 59 355
# Image over
# Final left coordinates 347 349 622 350
# Final right coordinates 856 463 218 485
# Image over
# Final left coordinates 324 317 602 319
# Final right coordinates 820 419 195 432
# Image over
# Final left coordinates 368 388 640 392
# Final right coordinates 858 322 210 358
# Image over
# Final left coordinates 338 385 617 390
# Final right coordinates 955 401 315 414
# Image over
# Final left coordinates 318 301 600 301
# Final right coordinates 923 458 317 475
# Image over
#  82%|████████▏ | 182/222 [00:02<00:00, 65.06it/s]
# Final left coordinates 335 493 617 504
# Final right coordinates 943 424 330 431
# Image over
# Final left coordinates 337 490 624 500
# Final right coordinates 1068 515 485 524
# Image over
#  85%|████████▌ | 189/222 [00:02<00:00, 64.92it/s]
# Final left coordinates 308 234 596 236
# Final right coordinates 993 380 386 388
# Image over
# Final left coordinates 372 498 644 509
# Final right coordinates 982 411 381 424
# Image over
# Final left coordinates 358 361 626 364
# Final right coordinates 958 460 358 474
# Image over
# Final left coordinates 377 426 649 427
# Final right coordinates 1021 445 409 452
# Image over
# Final left coordinates 378 263 649 265
# Final right coordinates 993 517 427 531
# Image over
# Final left coordinates 387 383 654 390
# Final right coordinates 962 405 373 412
# Image over
# Final left coordinates 348 408 625 415
# Final right coordinates 958 423 368 430
# Image over
# Final left coordinates 328 387 607 392
# Final right coordinates 908 468 293 480
# Image over
# Final left coordinates 370 434 643 444
# Final right coordinates 1052 457 421 472
# Image over
# Final left coordinates 376 333 660 335
# Final right coordinates 962 487 338 496
# Image over
# Final left coordinates 361 118 653 122
# Final right coordinates 1044 531 390 538
# Image over
#  88%|████████▊ | 196/222 [00:02<00:00, 64.13it/s]
# Final left coordinates 301 411 612 415
# Final right coordinates 685 377 58 384
# Image over
# Final left coordinates 373 507 665 518
# Final right coordinates 888 462 242 495
# Image over
# Final left coordinates
#  91%|█████████▏| 203/222 [00:03<00:00, 61.58it/s]
#  420 258 686 259
# Final right coordinates 927 462 289 474
# Image over
# Final left coordinates 394 246 659 247
# Final right coordinates 778 332 140 341
# Image over
# Final left coordinates 394 319 664 326
# Final right coordinates 840 409 231 415
# Image over
# Final left coordinates 366 300 631 300
# Final right coordinates 901 348 280 365
# Image over
# Final left coordinates 357 372 631 375
# Final right coordinates 1018 428 402 437
# Image over
# Final left coordinates 347 409 630 420
# Final right coordinates 965 404 336 415
# Image over
# Final left coordinates 366 375 641 378
# Final right coordinates 943 415 331 422
# Image over
# Final left coordinates 331 391 614 394
# Final right coordinates 1042 441 422 454
# Image over
# Final left coordinates 426 385 707 387
# Final right coordinates 880 493 287 531
# Image over
# Final left coordinates 361 351 651 354
# Final right coordinates 1031 371 405 386
# Image over
# Final left coordinates 339 502 628 516
# Final right coordinates 1012 414 425 423
# Image over
# Final left coordinates 351 413 635 416
# Final right coordinates 942 463 365 469
# Image over
# Final left coordinates 403 237 678 238
# Final right coordinates 923 492 338 496
# Image over
#  98%|█████████▊| 217/222 [00:03<00:00, 62.51it/s]
# Final left coordinates 403 392 666 393
# Final right coordinates 869 432 286 500
# Image over
# Final left coordinates 394 320 659 320
# Final right coordinates 905 350 308 360
# Image over
# Final left coordinates 377 390 648 400
# Final right coordinates 1152 334 545 341
# Image over
# Final left coordinates 370 495 637 496
# Final right coordinates 988 509 381 514
# Image over
# Final left coordinates 373 403 648 425
# Final right coordinates 895 388 293 396
# Image over
# Final left coordinates 399 167 677 170
# Final right coordinates 981 479 368 486
# Image over
# Final left coordinates 374 349 655 352
# Final right coordinates 931 400 318 418
# Image over
# Final left coordinates 335 460 619 471
# Final right coordinates 980 409 370 461
# Image over
# Final left coordinates 366 447 651 458
# Final right coordinates 807 498 204 538
# Image over
# Final left coordinates 361 360 631 363
# Final right coordinates 844 446 230 454
# Image over
# Final left coordinates 347 506
# 100%|█████████▉| 221/222 [00:03<00:00, 65.98it/s]
#  628 525
# Final right coordinates 837 338 211 369
# Image over
# Final left coordinates 351 357 622 359
# Final right coordinates 857 491 260 496
# Image over
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: test_videos_output/solidWhiteRight.mp4
#
# CPU times: user 3.38 s, sys: 755 ms, total: 4.13 s
# Wall time: 3.74 s

# %% [markdown]
# Play the video inline, or if you prefer find the video in your filesystem (should be in the same directory) and play it in your video player of choice.

# %%
HTML("""
<video width="960" height="540" controls>
  <source src="{0}">
</video>
""".format(white_output))
# Out:
# <video width="960" height="540" controls>
#   <source src="test_videos_output/solidWhiteRight.mp4">
# </video>

# %% [markdown]
# ## Improve the draw_lines() function
#
# **At this point, if you were successful with making the pipeline and tuning parameters, you probably have the Hough line segments drawn onto the road, but what about identifying the full extent of the lane and marking it clearly as in the example video (P1_example.mp4)?  Think about defining a line to run the full length of the visible lane based on the line segments you identified with the Hough Transform. As mentioned previously, try to average and/or extrapolate the line segments you've detected to map out the full extent of the lane lines. You can see an example of the result you're going for in the video "P1_example.mp4".**
#
# **Go back and modify your draw_lines function accordingly and try re-running your pipeline. The new output should draw a single, solid line over the left lane line and a single, solid line over the right lane line. The lines should start from the bottom of the image and extend out to the top of the region of interest.**

# %% [markdown]
# Now for the one with the solid yellow lane on the left. This one's more tricky!

# %%
yellow_output = 'test_videos_output/solidYellowLeft.mp4'
## To speed up the testing process you may want to try your pipeline on a shorter subclip of the video
## To do so add .subclip(start_second,end_second) to the end of the line below
## Where start_second and end_second are integer values representing the start and end of the subclip
## You may also uncomment the following line for a subclip of the first 5 seconds
##clip2 = VideoFileClip('test_videos/solidYellowLeft.mp4').subclip(0,5)
clip2 = VideoFileClip('test_videos/solidYellowLeft.mp4')
yellow_clip = clip2.fl_image(process_image)
# %time yellow_clip.write_videofile(yellow_output, audio=False)

# %%
HTML("""
<video width="960" height="540" controls>
  <source src="{0}">
</video>
""".format(yellow_output))

# %% [markdown]
# ## Writeup and Submission
#
# If you're satisfied with your video outputs, it's time to make the report writeup in a pdf or markdown file. Once you have this Ipython notebook ready along with the writeup, it's time to submit for review! Here is a [link](https://github.com/udacity/CarND-LaneLines-P1/blob/master/writeup_template.md) to the writeup template file.

# %% [markdown]
# ## Optional Challenge
#
# Try your lane finding pipeline on the video below.  Does it still work?  Can you figure out a way to make it more robust?  If you're up for the challenge, modify your pipeline so it works with this video and submit it along with the rest of your project!

# %%
challenge_output = 'test_videos_output/challenge.mp4'
## To speed up the testing process you may want to try your pipeline on a shorter subclip of the video
## To do so add .subclip(start_second,end_second) to the end of the line below
## Where start_second and end_second are integer values representing the start and end of the subclip
## You may also uncomment the following line for a subclip of the first 5 seconds
##clip3 = VideoFileClip('test_videos/challenge.mp4').subclip(0,5)
clip3 = VideoFileClip('test_videos/challenge.mp4')
challenge_clip = clip3.fl_image(process_image)
# %time challenge_clip.write_videofile(challenge_output, audio=False)

# %%
HTML("""
<video width="960" height="540" controls>
  <source src="{0}">
</video>
""".format(challenge_output))
